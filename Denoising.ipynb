# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[16,12]
plt.rcParams.update({'font.size':18})
dt=0.001
t=np.arange(0,1,dt)
f=np.cos(2*np.pi*50*t)+np.cos(2*np.pi*120*t)
f_clean=f
f=f+ 2.5*np.random.random(len(t))
plt.plot(t,f,color='c',LineWidth=1.5,label='Noisy')
plt.plot(t,f_clean,color='k',LineWidth=2,label='Clean')
plt.xlim(t[0],t[-1])
plt.legend()
# Out:
# C:\Users\RAKSHA\AppData\Local\Temp/ipykernel_10736/3244909315.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f,color='c',LineWidth=1.5,label='Noisy')
# C:\Users\RAKSHA\AppData\Local\Temp/ipykernel_10736/3244909315.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f_clean,color='k',LineWidth=2,label='Clean')

# %%
#Compute the FFT
n=len(t)
fhat=np.fft.fft(f,n)
PSD=fhat*np.conj(fhat)/n
freq=(1/(dt*n))*np.arange(n)
L=np.arange(1,np.floor(n/2),dtype='int')
fig,axs=plt.subplots(2,1)
plt.sca(axs[0])
plt.plot(t,f,color='c',LineWidth=1.5,label='Noisy')
plt.plot(t,f_clean,color='k',LineWidth=2,label='Clean')
plt.xlim(t[0],t[-1])
plt.legend()

plt.sca(axs[1])
plt.plot(freq[L],PSD[L],color='c',LineWidth=2,label='Noisy')
plt.xlim(freq[L[0]],freq[L[-1]])
plt.legend()
plt.show()
# Out:
# C:\Users\RAKSHA\AppData\Local\Temp/ipykernel_7200/3569094035.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f,color='c',LineWidth=1.5,label='Noisy')
# C:\Users\RAKSHA\AppData\Local\Temp/ipykernel_7200/3569094035.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f_clean,color='k',LineWidth=2,label='Clean')
# C:\Users\RAKSHA\AppData\Local\Temp/ipykernel_7200/3569094035.py:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(freq[L],PSD[L],color='c',LineWidth=2,label='Noisy')
# D:\Anaconda\lib\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
